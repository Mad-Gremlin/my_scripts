# %%
annotation = "/mnt/data/lizards/dasha/val/emapp_pep_val.emapper.annotations"
eggnog = "/mnt/data/lizards/dasha/unisex/pref_genes_eggnog_unisex.txt"
genes = []
genes2 = []
with open(eggnog) as eg:
    for line in eg:
        line = line.split()
        if len(line) == 1:
            genes.append(line)
        else:
            continue

# %%
genes = [g[0] for g in genes]

# %%
from itertools import groupby
genes = [el for el, _ in groupby(genes)]

# %%
print(*genes, sep = "\n")
# Out:
# Preferred_name
# SLC7A2
# GRM5
# SETMAR
# PTPRF
# PTPRJ
# BCL2L13
# AMA-1
# RBMS3
# SLC25A19
# VANGL1
# SPATA6
# KDSR
# BTBD6
# PHACTR2
# HYDIN
# PKIG
# SNRPA1
# RGS12
# NEK5
# SZT2
# MOCS1
# nmd3
# PDZRN3
# PDZD4
# PDZRN3
# PDZD4
# TMC8
# GSAP
# CCDC146
# GSAP
# CCDC146
# GSAP
# CCDC146
# GSAP
# CCDC146
# ARHGEF40
# CACNB1
# TRERF1
# CACNB1
# TBK1
# DCPS
# NFYC
# FEZF2
# klf17
# RNF17
# TPP2
# ARID4A
# FOXO3
# MORN2
# KCNIP4
# PACRGL
# MORN2
# KCNIP4
# PACRGL
# KCNIP4
# FOXP3
# SLC39A5
# MCAT
# C19orf71
# METTL17
# IFT27
# ASPM
# AGBL1
# SLC26A10
# SLC37A3
# ZNF536
# UFSP1
# C9orf84
# PITPNM3
# CAPN14
# PLA2G15
# MLLT1
# MGAT3
# TMEM204
# PDZD2
# TGM3
# ZNF219
# NAIF1
# NDST1
# HSF2
# KIF24
# PROB1
# ITGA5
# C5orf30
# SSH3
# ARFIP2
# TCTE1
# NCOR1
# CEBPA
# CTSL
# DPYSL4
# RGS3
# TRIB2
# LPCAT1
# CACNA1E
# ZRANB3
# BHLHE41
# WDYHV1
# RCC1
# PCSK2
# CHST2
# FOXF2
# PROK1
# SNAPC3
# SUN1
# FMO2
# ARSI
# TMIGD1
# TSTD3
# lbx2
# LBX1
# AUNIP
# PCDH10
# E2F8
# AMA-1
# TEX2
# RRP1B
# ...

# %%
len(genes)
# Out:
# 34302
